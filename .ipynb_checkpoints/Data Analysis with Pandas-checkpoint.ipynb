# %% [markdown]
# # Data Analysis with Pandas

# %% [markdown]
# ### Background
#
# Go to the main website https://pandas.pydata.org
#
# Pandas are pre-installed on conda, so no need to install. Go straight to the "Getting started" section.
#
# Spend a few minutes browsing the documentations and familiarise yourself with the main functionalities that the pandas library provides for data science.
#
# Here are some guiding questions for your initial reading:
#
# 1. What is a `DataFrame`?
# 2. If you're already familiar with Excel, how is pandas similar/different to Excel?
# 3. What type of data can be stored in a pandas DataFrame?
# 4. What are common operations on DataFrames?

# %% [markdown]
# ## A simple code example
#
# Read the following python code that creates a new pandas DataFrame.

# %%
import pandas as pd

# construct a data frame and display it
name_column = ['Peter', 'Paul', 'Mary', 'Jo']
age_column = [42, 23, 73, 16]
dfr = pd.DataFrame({'Name': name_column, 'Age': age_column})
dfr
# Out:
#     Name  Age
# 0  Peter   42
# 1   Paul   23
# 2   Mary   73
# 3     Jo   16

# %%
# add a column
dfr['Student'] = [True, True, False, False]
dfr
# Out:
#     Name  Age  Student
# 0  Peter   42     True
# 1   Paul   23     True
# 2   Mary   73    False
# 3     Jo   16    False

# %%
# Display only students
dfr[ dfr['Student'] == True ]
# Out:
#     Name  Age  Student
# 0  Peter   42     True
# 1   Paul   23     True

# %%
# Sort by age
dfr.sort_values(by='Age')
# Out:
#     Name  Age  Student
# 3     Jo   16    False
# 1   Paul   23     True
# 0  Peter   42     True
# 2   Mary   73    False

# %%
# Note that subsetting students and sorting by age does not change 
# the original dataframe. dfr is still the same:
dfr
# Out:
#     Name  Age  Student
# 0  Peter   42     True
# 1   Paul   23     True
# 2   Mary   73    False
# 3     Jo   16    False

# %% [markdown]
# ### Exercises
#
# 1. Create a new DataFrame `uk_gdp` with 2 columns: `Year` containing the numbers from 2000 to the current year, and `GDP` containing the UK's GDP.
# 2. Sort the DataFrame by increasing GDP.
# 3. Read the section on "Filtering specific rows of a DataFrame" on the pandas website. Pick some suitable GDP threshold and create a new DataFrame called `above` that contains only the years and GDP values where GDP was above the threshold.
# 4. Skim the help file on the `to_csv` method by typing `uk_gdp.to_csv()` in Jupyter, and hitting Shift-Tab twice. Read the examples section at the bottom.
# 5. Write the `uk_gdp` data frame to a csv file called `uk_gdp.csv`.
# 6. Open the saved csv file in Excel. Make some changes to the data in Excel and save the file. Then read the file back into a DataFrame in Jupyter, using the `pd.read_csv` function.

# %% [markdown]
# ### Solutions

# %%
# 2001 to 2020, from macrotrends.net, UK GDP in trillions USD, rounded
year_col = [y for y in range(2001, 2021)] 
gdp_col = [1.6, 1.8, 2.1, 2.4, 2.5, 2.7, 3.1, 2.9, 2.4, 2.4, 
           2.7, 2.7, 2.8, 3.1, 2.9, 2.7, 2.7, 2.9, 2.8, 2.7]
uk_gdp = pd.DataFrame({'Year':year_col, 'GDP':gdp_col})

# sort by gdp
uk_gdp.sort_values(by='GDP')

# only disply gdp > 3 trillion USD
thresh = 3.0
uk_gdp[ uk_gdp['GDP'] > thresh ]

# write to csv file
uk_gdp.to_csv("uk_gdp.csv")

# after making some changes to the file in excel, read it back into jupyter
uk_gdp_new = pd.read_csv("uk_gdp.csv")
uk_gdp_new
# Out:
#     Unnamed: 0  Year  GDP
# 0            0  2001  1.6
# 1            1  2002  1.8
# 2            2  2003  2.1
# 3            3  2004  2.4
# 4            4  2005  2.5
# 5            5  2006  2.7
# 6            6  2007  3.1
# 7            7  2008  2.9
# 8            8  2009  2.4
# 9            9  2010  2.4
# 10          10  2011  2.7
# 11          11  2012  2.7
# 12          12  2013  2.8
# 13          13  2014  3.1
# 14          14  2015  2.9
# 15          15  2016  2.7
# 16          16  2017  2.7
# 17          17  2018  2.9
# 18          18  2019  2.8
# 19          19  2020  2.7

# %% [markdown]
# ### Data

# %% [markdown]
# The comma-separated values (csv) file “Road Safety Data - Accidents 2019” was downloaded from
# https://data.gov.uk/dataset/cb7ae6f0-4be6-4935-9277-47e5ce24a11f/road-safety-data

# %% [markdown]
# Carefully read and execute the following data analysis code. Examine the code by printing some intermediate results. Read the documentation of some key functions. Add some comments to clarify what's happening. Then go on to answering the questions below.

# %%
import pandas as pd
accidents = pd.read_csv('accidents2019.csv', parse_dates=False)

# %%
accidents['Date'] = pd.to_datetime(accidents['Date'], format='%d/%m/%Y')

# %%
xmas_ruined = accidents[ accidents['Date'] == pd.to_datetime('2019-12-24') ]
xmas_ruined.shape[0]
# Out:
# 253

# %%
# look up LSOA by postcode at https://imd-by-postcode.opendatacommunities.org/imd/2019
unexe_lsoa = "E01020016" 
unexe = accidents[ accidents["LSOA_of_Accident_Location"] == unexe_lsoa]
# unexe[ ["Number_of_Vehicles", "Number_of_Casualties"] ]

# %%
# 1 is fatal, 2 is serious, 3 is mild
accidents.value_counts(['Accident_Severity'], normalize=True)
# Out:
# Accident_Severity
# 3                    0.786619
# 2                    0.199275
# 1                    0.014106
# dtype: float64

# %% [markdown]
# ### Warm-up problems

# %% [markdown]
# **How many rows and columns does `accidents` have?**

# %%
accidents.shape
# Out:
# (117536, 32)

# %% [markdown]
# **Create a new data frame locations that only consists of the `Latitude` and
# `Longitude` column of `accidents`.**

# %%
locations = accidents[['Latitude','Longitude']]
locations
# Out:
#          Latitude  Longitude
# 0       51.508057  -0.153842
# 1       51.436208  -0.127949
# 2       51.526795  -0.124193
# 3       51.546387  -0.191044
# 4       51.541121  -0.200064
# ...           ...        ...
# 117531  55.047323  -3.368899
# 117532  55.215407  -2.983499
# 117533  54.991685  -3.274645
# 117534  55.148292  -2.997491
# 117535  55.357237  -3.715064
#
# [117536 rows x 2 columns]

# %% [markdown]
# **Transform the `Date` column to the data type `datetime`.**

# %%
accidents.dtypes
# Out:
# Accident_Index                                  object
# Location_Easting_OSGR                          float64
# Location_Northing_OSGR                         float64
# Longitude                                      float64
# Latitude                                       float64
# Police_Force                                     int64
# Accident_Severity                                int64
# Number_of_Vehicles                               int64
# Number_of_Casualties                             int64
# Date                                            object
# Day_of_Week                                      int64
# Time                                            object
# Local_Authority_(District)                       int64
# Local_Authority_(Highway)                       object
# 1st_Road_Class                                   int64
# 1st_Road_Number                                  int64
# Road_Type                                        int64
# ...

# %%
ii = [1, 100]

# %%
accidents['Date'][ii]
# Out:
# 1      15/01/2019
# 100    03/01/2019
# Name: Date, dtype: object

# %%
dat = pd.to_datetime(accidents['Date'][ii])
dat
# Out:
# 1     2019-01-15
# 100   2019-03-01
# Name: Date, dtype: datetime64[ns]

# %%
dat.dt.month
# Out:
# 1      1
# 100    3
# Name: Date, dtype: int64

# %%
dat.dt.day
# Out:
# 1      15
# 100     1
# Name: Date, dtype: int64

# %% [markdown]
# The dates aren't parsed correctly! In the input file, the date format is `DD/MM/YYYY`, but `pd.to_datetime` wants to interpret dates as `MM/DD/YYYY` (the American standard), and only if that fails, for example if the month is greater than 12, will it consider alternatives. That is why the string `15/01/2019` is correctly interpreted as `2019-01-15`, but `03/01/2019` is incorrectly parsed as `2019-03-01`. To correct this behavior, we have to tell `pd.to_datetime()` exactly in what format the dates are stored in the string.

# %%
pd.to_datetime(accidents['Date'][ii], format="%d/%m/%Y")
# Out:
# 1     2019-01-15
# 100   2019-01-03
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# Now we can transform the whole Date column correctly.

# %%
accidents['Date'] = pd.to_datetime(accidents['Date'], format="%d/%m/%Y")
accidents
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       2019010128300               528218.0                180407.0
# 1       2019010152270               530219.0                172463.0
# 2       2019010155191               530222.0                182543.0
# 3       2019010155192               525531.0                184605.0
# 4       2019010155194               524920.0                184004.0
# ...               ...                    ...                     ...
# 117531  2019984106919               312635.0                573392.0
# 117532  2019984107019               337522.0                591682.0
# 117533  2019984107219               318544.0                567087.0
# 117534  2019984107419               336525.0                584226.0
# 117535  201998QC01004               291367.0                608364.0
#
#         Longitude   Latitude  Police_Force  Accident_Severity  \
# 0       -0.153842  51.508057             1                  3
# ...

# %% [markdown]
# **Permanently remove the columns `Accident_Index`, `Location_Easting_OSGR`, `Location_Northing_OSGR` from `accidents`.**

# %%
accidents.drop(['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR'], axis=1, inplace=True)

# %% [markdown]
# **Reorder the rows of the data frame by increasing Date and Time.**

# %%
accidents.sort_values(['Date', 'Time'], inplace=True)
accidents
# Out:
#         Longitude   Latitude  Police_Force  Accident_Severity  \
# 65479   -0.201080  52.781682            32                  2
# 14      -0.170889  51.496210             1                  3
# 68172    0.159444  52.676285            35                  3
# 58629   -1.391543  52.506762            23                  2
# 34803   -2.376181  53.360964             7                  2
# ...           ...        ...           ...                ...
# 117423  -3.594977  54.926262            98                  2
# 24824   -0.192109  51.536988             1                  3
# 79062    0.527620  51.789244            42                  2
# 24822   -0.182246  51.527942             1                  3
# 55182   -1.923558  52.482182            20                  3
#
#         Number_of_Vehicles  Number_of_Casualties       Date  Day_of_Week  \
# 65479                    2                     1 2019-01-01            3
# ...

# %% [markdown]
# **Add an `index` column with increasing integer values 1,2,3,...**

# %%
accidents['index'] = np.arange(1, accidents.shape[0]+1)
accidents
# Out:
#         Longitude   Latitude  Police_Force  Accident_Severity  \
# 65479   -0.201080  52.781682            32                  2
# 14      -0.170889  51.496210             1                  3
# 68172    0.159444  52.676285            35                  3
# 58629   -1.391543  52.506762            23                  2
# 34803   -2.376181  53.360964             7                  2
# ...           ...        ...           ...                ...
# 117423  -3.594977  54.926262            98                  2
# 24824   -0.192109  51.536988             1                  3
# 79062    0.527620  51.789244            42                  2
# 24822   -0.182246  51.527942             1                  3
# 55182   -1.923558  52.482182            20                  3
#
#         Number_of_Vehicles  Number_of_Casualties       Date  Day_of_Week  \
# 65479                    2                     1 2019-01-01            3
# ...

# %% [markdown]
# ### Advanced problems

# %% [markdown]
# **Add a column `hour` with values 0,1,2,. . . ,23 corresponding to the time of day.**

# %%
accidents['hour'] = pd.to_datetime(accidents['Time'], format="%H:%M").dt.hour
accidents
# Out:
#         Longitude   Latitude  Police_Force  Accident_Severity  \
# 65479   -0.201080  52.781682            32                  2
# 14      -0.170889  51.496210             1                  3
# 68172    0.159444  52.676285            35                  3
# 58629   -1.391543  52.506762            23                  2
# 34803   -2.376181  53.360964             7                  2
# ...           ...        ...           ...                ...
# 117423  -3.594977  54.926262            98                  2
# 24824   -0.192109  51.536988             1                  3
# 79062    0.527620  51.789244            42                  2
# 24822   -0.182246  51.527942             1                  3
# 55182   -1.923558  52.482182            20                  3
#
#         Number_of_Vehicles  Number_of_Casualties       Date  Day_of_Week  \
# 65479                    2                     1 2019-01-01            3
# ...

# %% [markdown]
# **Add a column `weekend` which is `True` for accidents that happened on the weekend, and `False` otherwise.**

# %%
accidents['weekday'] = accidents['Date'].dt.strftime('%A')

# %%
accidents['weekend'] = accidents['weekday'].isin(['Saturday','Sunday'])

# %%
accidents.drop('weekday', axis=1, inplace=True)

# %%
accidents.value_counts(['weekend'])
# Out:
# weekend
# False      89045
# True       28491
# dtype: int64

# %% [markdown]
# **Create a new data frame called total that with columns `Date` (in format ‘YYYY-MM-DD’), `Accidents` (total number of accidents per day) and `Casualties` (total number of casualties per day).**

# %%
accidents.groupby('Date').size().rename('Accidents')
# Out:
# Date
# 2019-01-01    231
# 2019-01-02    193
# 2019-01-03    217
# 2019-01-04    233
# 2019-01-05    194
#              ...
# 2019-12-27    204
# 2019-12-28    174
# 2019-12-29    163
# 2019-12-30    245
# 2019-12-31    232
# Name: Accidents, Length: 365, dtype: int64

# %%
# group by date and count number of entries in each group using size, then rename to Accidents
daily_count = accidents.groupby('Date').size().rename('Accidents')
# group by date, extract number of casualties, and calculate the sum in each group, then rename
daily_casualties = accidents.groupby('Date')['Number_of_Casualties'].agg(np.sum).rename('Casualties')

# %%
daily_count
# Out:
# Date
# 2019-01-01    231
# 2019-01-02    193
# 2019-01-03    217
# 2019-01-04    233
# 2019-01-05    194
#              ...
# 2019-12-27    204
# 2019-12-28    174
# 2019-12-29    163
# 2019-12-30    245
# 2019-12-31    232
# Name: Accidents, Length: 365, dtype: int64

# %%
daily_casualties
# Out:
# Date
# 2019-01-01    299
# 2019-01-02    252
# 2019-01-03    290
# 2019-01-04    292
# 2019-01-05    263
#              ...
# 2019-12-27    278
# 2019-12-28    241
# 2019-12-29    212
# 2019-12-30    332
# 2019-12-31    334
# Name: Casualties, Length: 365, dtype: int64

# %%
# now merge the two Series, making sure the correct Dates are matched
daily = pd.merge(left=daily_count, right=daily_casualties, on='Date')
daily
# Out:
#             Accidents  Casualties
# Date
# 2019-01-01        231         299
# 2019-01-02        193         252
# 2019-01-03        217         290
# 2019-01-04        233         292
# 2019-01-05        194         263
# ...               ...         ...
# 2019-12-27        204         278
# 2019-12-28        174         241
# 2019-12-29        163         212
# 2019-12-30        245         332
# 2019-12-31        232         334
#
# [365 rows x 2 columns]

# %% [markdown]
# **Verify that Casualties is always bigger than Accidents.**

# %%
np.all(daily['Casualties'] >= daily['Accidents'])
# Out:
# True

# %% [markdown]
# **Create a time series plot showing the number of accidents per day.**

# %%
plt.plot('Accidents', data=daily)
plt.show()

# %% [markdown]
# **Summarise and plot the number of accidents for each weekday, and for each hour of the day.**

# %%
daily['weekday'] = daily.index.day_name()

# %%
acc_weekday = daily.groupby(['weekday'])['Accidents'].agg([np.sum])

# %%
acc_weekday = acc_weekday.rename({'sum':'Accidents'}, axis=1)

# %%
# bring weekdays into correct order
acc_weekday = acc_weekday.iloc[[1,5,6,4,0,2,3]]

# %%
acc_weekday
# Out:
#            Accidents
# weekday
# Monday         16643
# Tuesday        17598
# Wednesday      17775
# Thursday       17973
# Friday         19056
# Saturday       15556
# Sunday         12935

# %%
plt.figure(figsize=[8,4])
plt.bar(acc_weekday.index, acc_weekday.Accidents)
plt.show()

# %% [markdown]
# **What was the day of the week of the 10 days with the highest number of casualties?**

# %%
daily.sort_values('Casualties', ascending=False)[:10][['Casualties','weekday']]
# Out:
#             Casualties    weekday
# Date
# 2019-12-04         606  Wednesday
# 2019-11-29         591     Friday
# 2019-11-08         590     Friday
# 2019-09-20         589     Friday
# 2019-12-20         577     Friday
# 2019-11-01         577     Friday
# 2019-10-02         562  Wednesday
# 2019-06-21         560     Friday
# 2019-12-02         557     Monday
# 2019-11-27         556  Wednesday
